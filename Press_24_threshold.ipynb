# %%
import pymongo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from datetime import datetime, timedelta

# %%
def press_plotter_24(category):
    press = "Press_24"

    myclient_global = pymongo.MongoClient(host = "128.121.34.13",connect = True)
    press_db = myclient_global[press]

    df = pd.read_excel(r"C:\Users\achakraborty\Downloads\_P24_live_DataPoints.xlsx",sheet_name = 'Sheet1')
    tag_name = df['Tag Name']
    tag_name = list(tag_name)
    sensor_class = df['Class']
    sensor_class = list(sensor_class)

    print(len(sensor_class),len(tag_name))

    tags = []
    for i in range(len(sensor_class)):
        if sensor_class[i] == category:
            tags.append(tag_name[i])

    print(tags)
    print(len(tags))
    print(tag_name)

    batch_info_dict = {} #empty dict

    for column in tags:
        for batch in [1,2,3,4]:
            collection = "BATCH_"+str(batch) #collection in db
            col = press_db[collection]
            results = col.find().limit(1).sort("_id",-1) # getting the first entry in db
            recent_doc = results[0] #getting the first entry in db
            if column in recent_doc.keys():
                if batch not in batch_info_dict:
                    batch_info_dict[batch] = [column]
                else:
                    batch_info_dict[batch].append(column)
    print(batch_info_dict)
    batch_info_dict.keys()

    tot = 0
    for batch in batch_info_dict:
        tot += len(batch_info_dict[batch])
    print(tot)

    quantiles = pd.DataFrame()

    for key in batch_info_dict.keys():
        batch = "BATCH_" + str(key)
        collection= press_db[batch]

        fields = batch_info_dict[key]

        earliest_date = collection.find_one({}, {"Date": 1}, sort=[("Date", 1)])['Date']
        print(earliest_date)

        # start = datetime.strptime(earliest_date, "%d-%b-%Y %H:%M:%S.%f") + timedelta(days=15)
        start = datetime(2023,6,12,0,0,0)
        end   = start + timedelta(days=5)
        

        projection = {}
        projection['_id'] = 0
        projection['Date'] = 1
        projection['Press_Angle'] = 1
        for field in fields:
            projection[field] = 1

        print(len(projection),projection)

        QUERY = {'$and':[{"Date": {'$gte': start, '$lt':  end}},{"Press_Angle" : {'$gte':0, '$lte': 200}}]}
        results = collection.find(QUERY,projection)
        df1 = pd.DataFrame(results).set_index('Date')
        df1.reset_index(inplace=True)
        df1.index = range(1, len(df1) + 1)
        describe = df1.describe().T
        # print(describe)
        # df1.head()

        # chunk_size = 500

        # # Split the dataframe into smaller chunks
        # df_chunks = [df1[i:i+chunk_size] for i in range(0, len(df1), chunk_size)]

        # # Filter out chunks with zero standard deviation in 'Col1Gibbs'
        # filtered_chunks = [chunk for chunk in df_chunks if np.std(chunk['Press_Angle']) != 0]

        # filtered_df = pd.concat(filtered_chunks, ignore_index=True)

        def filtered(df,minutes=40*1*60):
            '''
            By default function filters out every minute when press isn't running (40 datapoints per second times 60 seconds per minute)
            This can be changed by specifying minute variable

            Example:
            filtered(df) would filter data for every minute press isn't running
            filtred(df,5) would filter data for every 5 minutes press isn't running
            '''
            
            # Split the dataframe into smaller chunks
            df_chunks = [df[i:i+minutes] for i in range(0, len(df), minutes)]

            # Filter out chunks with zero standard deviation in 'Press_Angle'
            filtered_chunks = [chunk for chunk in df_chunks if np.std(chunk['Press_Angle']) != 0]

            filtered_df = pd.concat(filtered_chunks, ignore_index=True)

            return filtered_df
        
        filtered_df = filtered(df1)

        result = []  # List to store the percentiles

        quantile = filtered_df.quantile([0.005,0.995], axis = 0)
        quantile = quantile.drop('Date', axis='columns')

        # for column in df.columns:
        #     column_percentiles = np.percentile(df[column], [5,95])
        #     result.append(column_percentiles)

        # for i in range(len(filtered_df)):
        #     column_percentiles = df[df.columns[i]].quantile([0.05, 0.95])
        #     result.append(column_percentiles.tolist())

        quantiles = pd.concat([quantiles, quantile], axis=1)
            

        # for i in range(len(df1.columns)):
        #     if df1.columns[i].endswith('Arms'):
        #         plt.plot(filtered_df.iloc[:,i],color='black')
        #         plt.ylabel(df1.columns[i])
        #         plt.xlabel("Date")
        #         plt.xticks(rotation=90)
        #         plt.ylim(0,3)
        #         plt.show()
        #     elif df1.columns[i].endswith('Vrms'):
        #         plt.plot(filtered_df.iloc[:,i],color='black')
        #         plt.ylabel(df1.columns[i])
        #         plt.xlabel("Date")
        #         plt.xticks(rotation=90)
        #         plt.ylim(0,0.01)
        #         plt.show()
        #     else:
        #         plt.plot(filtered_df.iloc[:,i],color='black')
        #         plt.ylabel(df1.columns[i])
        #         plt.xlabel("Date")
        #         plt.xticks(rotation=90)
        #         plt.show()

    return quantiles.T

# %%
if __name__ == '__main__':
    quantiles = pd.DataFrame()
    categories = ['BOLSTER','CROWN','FEEDLINE','HYDRAULIC','LUBRICATION','PNEUMATIC','RAM','TRANSFER']
    for category in categories:
        quantile = press_plotter_24(category)
        quantile = quantile.drop(quantile.index[0])
        quantiles = pd.concat([quantiles,quantile],axis=0)
    # print(quantiles)

    sensor_dict = {}
    for i in range(len(quantiles)):
        index = quantiles.index.to_list()[i]
        thresholds = quantiles.iloc[i].to_list()
        sensor_dict[index] = thresholds

    print(sensor_dict) ## this dictionary gives the threshold values
# Out:
# 228 228
# ['DieClamp1_Pre', 'DieClamp2_Pre', 'QDC_UnClamp_Pre', 'QDC_Clamp_Pre', 'QDC_Lift_Pre', 'MainHPU_Psressure_Pre', 'Pnmatic_Driving_Pre']
# 7
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle', nan, 'FR_Gb_Cnd_Vrms', 'FR_Gb_Cnd_Apk', 'FR_Gb_Cnd_Arms', 'FR_Gb_Cnd_Crst', 'FR_Gb_Cnd_Temp', 'FL_Gb_Cnd_Vrms', 'FL_Gb_Cnd_Apk', 'FL_Gb_Cnd_Arms', 'FL_Gb_Cnd_Crst', 'FL_Gb_Cnd_Temp', 'RR_Gb_Cnd_Vrms', 'RR_Gb_Cnd_Apk', 'RR_Gb_Cnd_Arms', 'RR_Gb_Cnd_Crst', 'RR_Gb_Cnd_Temp', 'RL_Gb_Cnd_Vrms', 'RL_Gb_Cnd_Apk', 'RL_Gb_Cnd_Arms', 'RL_Gb_Cnd_Crst', 'RL_Gb_Cnd_Temp', 'Ram_FR_CNut_Vrms', 'Ram_FR_CNut_Apk', 'Ram_FR_CNut_Arms', 'Ram_FR_CNut_Crst', 'Ram_FR_CNut_Temp', 'Ram_FL_CNut_Vrms', 'Ram_FL_CNut_Apk', 'Ram_FL_CNut_Arms', 'Ram_FL_CNut_Crst', 'Ram_FL_CNut_Temp', 'Ram_RR_CNut_Vrms', 'Ram_RR_CNut_Apk', 'Ram
{'_id': 0, 'Date': 1, 'Press_Angle': 1, 'DieClamp1_Pre': 1, 'DieClamp2_Pre': 1, 'QDC_UnClamp_Pre': 1, 'QDC_Clamp_Pre': 1, 'QDC_Lift_Pre': 1, 'MainHPU_Psressure_Pre': 1, 'Pnmatic_Driving_Pre': 1}
# 228 228
# ['FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle']
# 76
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle', nan, 'FR_Gb_Cnd_Vrms', 'FR_Gb_Cnd_Apk', 'FR_Gb_Cnd_Arms', 'FR_Gb_Cnd_Crst', 'FR_Gb_Cnd_Temp', 'FL_Gb_Cnd_Vrms', 'FL_Gb_C
_RevPre', 'uncolr_Mandrel_ret_Pre', 'uncolr_Mandrel_Exp_Pre', 'uncolr_Mandrel_JgFwd_Pre', 'uncolr_Mandrel_JgRev_Pre', 'uncolr_ClutchnBrake_Pre', nan, 'DieClamp1_Pre', 'DieClamp2_Pre', 'QDC_UnClamp_Pre', 'QDC_Clamp_Pre', 'QDC_Lift_Pre', 'MainHPU_Psressure_Pre', 'Pnmatic_Driving_Pre', nan, 'CF_LubeBlock_Pre' ...
# {1: ['FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp'], 3: ['RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp']}
# 55
# 26-J
# 33 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'FL_UprLink_Pin_Vrms': 1, 'FL_UprLink_Pin_Apk': 1, 'FL_UprLink_Pin_Arms': 1, 'FL_UprLink_Pin_Crst': 1, 'FL_UprLink_Pin_Temp': 1, 'FR_UprLink_Pin_Vrms': 1, 'FR_UprLink_Pin_Apk': 1, 'FR_UprLink_Pin_Arms': 1, 'FR_UprLink_Pin_Crst': 1, 'FR_UprLink_Pin_Temp': 1, 'FL_Eccntric_Pin_Vrms': 1, 'FL_Eccntric_Pin_Apk': 1, 'FL_Eccntric_Pin_Arms': 1, 'FL_Eccntric_Pin_Crst': 1, 'FL_Eccntric_Pin_TempFar': 1, 'FR_Eccntric_Pin_Vrms': 1, 'FR_Eccntric_Pin_Apk': 1, 'FR_Eccntric_Pin_Arms': 1, 'FR_Eccntric_Pin_Crst': 1, 'FR_Eccntric_Pin_Temp': 1, 'Frnt_InterPin_Vrms': 1, 'Frnt_InterPin_Apk': 1, 'Frnt_InterPin_Arms': 1, 'Frnt_InterPin_Crst': 1, 'Frnt_InterPin_Temp': 1, 'Drive_Shaft_Pin_Vrms': 1, 'Drive_Shaft_Pin_Apk': 1, 'Drive_Shaft_Pin_Arms': 1, 'Drive_Shaft_Pin_Crst': 1, 'Drive_Shaft_Pin_Temp': 1}
# 01-Feb-2023 00:28:11.964199
# 28 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'RL_UprLink_Bshg_Vrms': 1, 'RL_UprLink_Bshg_Apk': 1, 'RL_UprLink_Bshg_Arms': 1, 'RL_UprLink_Bshg_Crst': 1, 'RL_UprLink_Bshg_Temp': 1, 'RR_UprLink_Bshg_Vrms': 1, 'RR_UprLink_Bshg_Apk': 1, 'RR_UprLink_Bshg_Arms': 1, 'RR_UprLink_Bshg_Crst': 1, 'RR_UprLink_Bshg_Temp': 1, 'RL_EccntricBshg_Vrms': 1, 'RL_EccntricBshg_Apk': 1, 'RL_EccntricBshg_Arms': 1, 'RL_EccntricBshg_Crst': 1, 'RL_EccntricBshg_Temp': 1, 'RR_EccntricBshg_Vrms': 1, 'RR_EccntricBshg_Apk': 1, 'RR_EccntricBshg_Arms': 1, 'RR_EccntricBshg_Crst': 1, 'RR_EccntricBshg_Temp': 1, 'FlyWhlShaftBshg_Outside_Vrms': 1, 'FlyWhlShaftBshg_Outside_Apk': 1, 'FlyWhlShaftBshg_Outside_Arms': 1, 'FlyWhlShaftBshg_Outside_Crst': 1, 'FlyWhlShaftBshg_Outside_Temp': 1}
# 228 228
# ['Fdr_Pnch_Rler_Pnmatic_Pre', 'Fdr_UpDwn_Pnmatic_Pre', 'Fdr_Guide_Pre', 'Stnr_Pinch_Roller_Pre', 'Stnr_Mtr_Vrms', 'Stnr_Mtr_Apk', 'Stnr_Mtr_Arms', 'Stnr_Mtr_Crst', 'Stnr_Mtr_Temp', 'Stnr_Pmp_HydPre', 'Stnr_Pmp_Vrms', 'Stnr_Pmp_Apk', 'Stnr_Pmp_Arms', 'Stnr_Pmp_Crst', 'Stnr_Pmp_Temp', 'Stnr_HydResvr_OilLvl', 'Stnr_HydMtrVrms', 'Stnr_HydMtrApk', 'Stnr_HydMtrArms', 'Stnr_HydMtrCrst', 'Stnr_HydMtrTemp', 'Stnr_MandrelArmRoller_FwdPre', 'Stnr_MandrelArmRoller_RevPre', 'uncolr_Mandrel_ret_Pre', 'uncolr_Mandrel_Exp_Pre', 'uncolr_Mandrel_JgFwd_Pre', 'uncolr_Mandrel_JgRev_Pre', 'uncolr_ClutchnBrake_Pre']
# 28
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle', nan, 'FR_Gb_Cnd_Vrms', 'FR_Gb_Cnd_Apk', 'FR_Gb_Cnd_Arms', 'FR_Gb_Cnd_
{'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Stnr_Pinch_Roller_Pre': 1, 'Stnr_Mtr_Vrms': 1, 'Stnr_Mtr_Apk': 1, 'Stnr_Mtr_Arms': 1, 'Stnr_Mtr_Crst': 1, 'Stnr_Mtr_Temp': 1}
# 228 228
# ['Crwn_HydUnit_Resvr_OilLvl', 'Crwn_HydUnit_HydClutch_Pre', 'Crwn_HydUnit_HydraulicPre', 'Crwn_HydUnit_HydMtrVrms', 'Crwn_HydUnit_HydMtrApk', 'Crwn_HydUnit_HydMtrArms', 'Crwn_HydUnit_HydMtrCrst', 'Crwn_HydUnit_HydMtrTemp', 'Crwn_HydUnit_HydPmp_Vrms', 'Crwn_HydUnit_HydPmp_Apk', 'Crwn_HydUnit_HydPmp_Arms', 'Crwn_HydUnit_HydPmp_Crst', 'Crwn_HydUnit_HydPmp_Temp', 'RadMtr_Vrms', 'RadMtr_Apk', 'RadMtr_Arms', 'RadMtr_Crst', 'RadMtr_Temp']
# 18
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 
# ['CF_LubeBlock_Pre', 'FL_Eccntric_LubePre', 'Ram_FR_EccntricLube_Pre', 'RR_Eccntric_LubePre', 'RL_Eccntric_LubePre', 'FL_Pitman_LubePre', 'Ram_FR_PitmanLube_Pre', 'RL_Pitman_LubePre', 'RR_Pitman_LubePre', 'Ram_FR_CNut_Lube_Pre', 'Ram_FL_CNut_Lube_Pre', 'Ram_RR_CNut_Lube_Pre', 'Ram_RL_CNut_Lube_Pre', 'Rear_LubeBlock_Pre', 'Pit_Hyd_Prefilter_Real_PSI', 'Pit_HydPre_Postfilter_Real_PSI', 'Pit_HydOverload_Pre_Real_PSI', 'Pit_Pmp_Vrms', 'Pit_Pmp_Apk', 'Pit_Pmp_Arms', 'Pit_Pmp_Crst', 'Pit_Pmp_Temp', 'Pit_LubeLevel', 'Pit_Mtr_Vrms', 'Pit_Mtr_Apk', 'Pit_Mtr_Arms', 'Pit_Mtr_Crst', 'Pit_Mtr_Temp', 'PitFlood']
# 29
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWh
_Temp', nan, nan, 'Fdr_Pnch_Rler_Pnmatic_Pre', 'Fdr_UpDwn_Pnmatic_Pre', 'Fdr_Guide_Pre', 'Stnr_Pinch_Roller_Pre', 'Stnr_Mtr_Vrms', 'Stnr_Mtr_Apk', 'Stnr_Mtr_Arms', 'Stnr_Mtr_Crst', 'Stnr_Mtr_Temp', 'Stnr_Pmp_HydPre', 'Stnr_Pmp_Vrms', 'Stnr_Pmp_Apk', 'Stnr_Pmp_Arms', 'Stnr_Pmp_Crst', 'Stnr_Pmp_Temp', 'Stnr_HydResvr_OilLvl', 'Stnr_HydMtrVrms', 'Stnr_HydMtrApk', 'Stnr_HydMtrArms', 'Stnr_HydMtrCrst', 'Stnr_HydMtrTemp', 'Stnr_MandrelArmRoller_FwdPre', 'Stnr_MandrelArmRoller_RevPre', 'uncolr_Mandrel_ret_Pre', 'uncolr_Mandrel_Exp_Pre', 'uncolr_Mandrel_JgFwd_Pre', 'uncolr_Mandrel_JgRev_Pre', 'uncolr_ClutchnBrake_Pre', nan, 'DieClamp1_Pre', 'DieClamp2_Pre', 'QDC_UnClamp_Pre', 'QDC_Clamp_Pre', 'QDC_Lift_Pre', 'MainHPU_Psressure_Pre', 'Pnmatic_Driving_Pre', nan, 'CF_LubeBlock_Pre' ...
# {2: ['Ram_FR_CNut_Lube_Pre', 'Ram_FL_CNut_Lube_Pre', 'Ram_RR_CNut_Lube_Pre', 'Ram_RL_CNut_Lube_Pre'], 3: ['Rear_LubeBlock_Pre'], 4: ['Pit_Hyd_Prefilter_Real_PSI', 'Pit_HydPre_Postfilter_Real_PSI', 'Pit_HydOverload_Pre_Real_PSI', 'Pit_Pmp_Vrms', 'Pit_Pmp_Apk', 'Pit_Pmp_Arms', 'Pit_Pmp_Crst', 'Pit_Pmp_Temp', 'Pit_LubeLevel', 'Pit_Mtr_Vrms', 'Pit_Mtr_Apk', 'Pit_Mtr_Arms', 'Pit_Mtr_Crst', 'Pit_Mtr_Temp', 'PitFlood']}
# 20
# 01-Feb-2023 00:28:11.953153
# 7 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Ram_FR_CNut_Lube_Pre': 1, 'Ram_FL_CNut_Lube_Pre': 1, 'Ram_RR_CNut_Lube_Pre': 1, 'Ram_RL_CNut_Lube_Pre': 1}
# 01-Feb-2023 00:28:11.964199
# 4 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Rear_LubeBlock_Pre': 1}
# 01-Feb-2023 00:28:11.923892
# 18 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Pit_Hyd_Prefilter_Real_PSI': 1, 'Pit_HydPre_Postfilter_Real_PSI': 1, 'Pit_HydOverload_Pre_Real_PSI': 1, 'Pit_Pmp_Vrms': 1, 'Pit_Pmp_Apk': 1, 'Pit_Pmp_Arms': 1, 'Pit_Pmp_Crst': 1, 'Pit_Pmp_Temp': 1, 'Pit_LubeLevel': 1, 'Pit_Mtr_Vrms': 1, 'Pit_Mtr_Apk': 1, 'Pit_Mtr_Arms': 1, 'Pit_Mtr_Crst': 1, 'Pit_Mtr_Temp': 1, 'PitFlood': 1}
# 228 228
# ['CBal_pre_PSI', 'QDC_Drive_Pre_PSI', 'LCBal_Resvr_Pre_PSI', 'RCBal_Resvr_Pre']
# 4
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle', nan, 'FR_Gb_Cnd_Vrms', 'FR_G
HydMtrApk', 'Stnr_HydMtrArms', 'Stnr_HydMtrCrst', 'Stnr_HydMtrTemp', 'Stnr_MandrelArmRoller_FwdPre', 'Stnr_MandrelArmRoller_RevPre', 'uncolr_Mandrel_ret_Pre', 'uncolr_Mandrel_Exp_Pre', 'uncolr_Mandrel_JgFwd_Pre', 'uncolr_Mandrel_JgRev_Pre', 'uncolr_ClutchnBrake_Pre', nan, 'DieClamp1_Pre', 'DieClamp2_Pre', 'QDC_UnClamp_Pre', 'QDC_Clamp_Pre', 'QDC_Lift_Pre', 'MainHPU_Psressure_Pre', 'Pnmatic_Driving_Pre', nan, 'CF_LubeBlock_Pre' ...
# {2: ['CBal_pre_PSI', 'QDC_Drive_Pre_PSI'], 4: ['LCBal_Resvr_Pre_PSI', 'RCBal_Resvr_Pre']}
# 4
# 01-Feb-2023 00:28:11.953153
# 5 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'CBal_pre_PSI': 1, 'QDC_Drive_Pre_PSI': 1}
# 01-Feb-2023 00:28:11.923892
# 5 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'LCBal_Resvr_Pre_PSI': 1, 'RCBal_Resvr_Pre': 1}
# 228 228
# ['FR_Gb_Cnd_Vrms', 'FR_Gb_Cnd_Apk', 'FR_Gb_Cnd_Arms', 'FR_Gb_Cnd_Crst', 'FR_Gb_Cnd_Temp', 'FL_Gb_Cnd_Vrms', 'FL_Gb_Cnd_Apk', 'FL_Gb_Cnd_Arms', 'FL_Gb_Cnd_Crst', 'FL_Gb_Cnd_Temp', 'RR_Gb_Cnd_Vrms', 'RR_Gb_Cnd_Apk', 'RR_Gb_Cnd_Arms', 'RR_Gb_Cnd_Crst', 'RR_Gb_Cnd_Temp', 'RL_Gb_Cnd_Vrms', 'RL_Gb_Cnd_Apk', 'RL_Gb_Cnd_Arms', 'RL_Gb_Cnd_Crst', 'RL_Gb_Cnd_Temp', 'Ram_FR_CNut_Vrms', 'Ram_FR_CNut_Apk', 'Ram_FR_CNut_Arms', 'Ram_FR_CNut_Crst', 'Ram_FR_CNut_Temp', 'Ram_FL_CNut_Vrms', 'Ram_FL_CNut_Apk', 'Ram_FL_CNut_Arms', 'Ram_FL_CNut_Crst', 'Ram_FL_CNut_Temp', 'Ram_RR_CNut_Vrms', 'Ram_RR_CNut_Apk', 'Ram_RR_CNut_Arms', 'Ram_RR_CNut_Crst', 'Ram_RR_CNut_Temp', 'Ram_RL_CNut_Vrms', 'Ram_RL_CNut_Apk', 'Ram_RL_CNut_Arms', 'Ram_RL_CNut_Crst', 'Ram_RL_CNut_Temp', 'Ram_Adj_Mtr_Vrms', 'Ram_Adj_Mtr_Apk', 'Ram_Adj_Mtr_Arms', 'Ram_Adj_Mtr_Crest', 'Ram_Adj_Mtr_Temp']
# 45
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle', nan, 'FR_Gb_Cnd_Vrms', 'FR_Gb_Cnd_Apk', 'FR_Gb_Cnd_Arms', 'FR_Gb_Cnd_Crst', 'FR_Gb_Cnd_Temp', 'FL_Gb_Cnd_Vrms', 'FL_Gb_Cnd_Apk', 'FL_Gb_Cnd_Arms', 'FL_Gb_Cnd_Crst', 'FL_Gb_Cnd_Temp', 'RR_Gb_Cnd_Vrms', 'RR_Gb_Cnd_Apk', 'RR_Gb_Cnd_Arms', 'R
{'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Ram_FR_CNut_Vrms': 1, 'Ram_FR_CNut_Apk': 1, 'Ram_FR_CNut_Arms': 1, 'Ram_FR_CNut_Crst': 1, 'Ram_FR_CNut_Temp': 1, 'Ram_FL_CNut_Vrms': 1, 'Ram_FL_CNut_Apk': 1, 'Ram_FL_CNut_Arms': 1, 'Ram_FL_CNut_Crst': 1, 'Ram_FL_CNut_Temp': 1, 'Ram_RR_CNut_Vrms': 1, 'Ram_RR_CNut_Apk': 1, 'Ram_RR_CNut_Arms': 1, 'Ram_RR_CNut_Crst': 1, 'Ram_RR_CNut_Temp': 1, 'Ram_RL_CNut_Vrms': 1, 'Ram_RL_CNut_Apk': 1, 'Ram_RL_CNut_Arms': 1, 'Ram_RL_CNut_Crst': 1, 'Ram_RL_CNut_Temp': 1}
# 01-Feb-2023 00:28:11.964199
# 8 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Ram_Adj_Mtr_Vrms': 1, 'Ram_Adj_Mtr_Apk': 1, 'Ram_Adj_Mtr_Arms': 1, 'Ram_Adj_Mtr_Crest': 1, 'Ram_Adj_Mtr_Temp': 1}
# 228 228
# ['Xfer_MainPre_PSI', 'Xfer_UnitHydMtr_Apk', 'Xfer_UnitHydMtr_Vrms', 'Xfer_UnitHydMtr_Arms', 'Xfer_UnitHydMtr_Crest', 'Xfer_UnitHydMtr_Temp', 'XferHyd_Pre', 'Xfer_HydUnit_OilLvl_UGT526inmm', 'Xfer_UnitHydMtr_Vrms', 'Xfer_UnitHydMtr_Apk', 'Xfer_UnitHydMtr_Arms', 'Xfer_UnitHydMtr_Crst', 'Xfer_UnitHydMtr_Temp']
# 13
# [nan, 'FL_UprLink_Pin_Vrms', 'FL_UprLink_Pin_Apk', 'FL_UprLink_Pin_Arms', 'FL_UprLink_Pin_Crst', 'FL_UprLink_Pin_Temp', 'FR_UprLink_Pin_Vrms', 'FR_UprLink_Pin_Apk', 'FR_UprLink_Pin_Arms', 'FR_UprLink_Pin_Crst', 'FR_UprLink_Pin_Temp', 'RL_UprLink_Bshg_Vrms', 'RL_UprLink_Bshg_Apk', 'RL_UprLink_Bshg_Arms', 'RL_UprLink_Bshg_Crst', 'RL_UprLink_Bshg_Temp', 'RR_UprLink_Bshg_Vrms', 'RR_UprLink_Bshg_Apk', 'RR_UprLink_Bshg_Arms', 'RR_UprLink_Bshg_Crst', 'RR_UprLink_Bshg_Temp', 'FL_Eccntric_Pin_Vrms', 'FL_Eccntric_Pin_Apk', 'FL_Eccntric_Pin_Arms', 'FL_Eccntric_Pin_Crst', 'FL_Eccntric_Pin_TempFar', 'FR_Eccntric_Pin_Vrms', 'FR_Eccntric_Pin_Apk', 'FR_Eccntric_Pin_Arms', 'FR_Eccntric_Pin_Crst', 'FR_Eccntric_Pin_Temp', 'RL_EccntricBshg_Vrms', 'RL_EccntricBshg_Apk', 'RL_EccntricBshg_Arms', 'RL_EccntricBshg_Crst', 'RL_EccntricBshg_Temp', 'RR_EccntricBshg_Vrms', 'RR_EccntricBshg_Apk', 'RR_EccntricBshg_Arms', 'RR_EccntricBshg_Crst', 'RR_EccntricBshg_Temp', 'Frnt_InterPin_Vrms', 'Frnt_InterPin_Apk', 'Frnt_InterPin_Arms', 'Frnt_InterPin_Crst', 'Frnt_InterPin_Temp', 'Rear_InterPin_Bshg_Vrms/R_I_P_Bshg_Vrms after 17 Mar', 'Rear_InterPin_Bshg_Apk', 'Rear_InterPin_Bshg_Arms', 'Rear_InterPin_Bshg_Crst', 'Rear_InterPin_Bshg_Temp', 'Drive_Shaft_Pin_Vrms', 'Drive_Shaft_Pin_Apk', 'Drive_Shaft_Pin_Arms', 'Drive_Shaft_Pin_Crst', 'Drive_Shaft_Pin_Temp', 'FlyWhl_InsideBshg_Vrms', 'FlyWhl_InsideBshg_Apk', 'FlyWhl_InsideBshg_Crst', 'FlyWhl_InsideBshg_Arms', 'FlyWhl_InsideBshg_Temp', 'FlyWhlShaftBshg_Outside_Vrms', 'FlyWhlShaftBshg_Outside_Apk', 'FlyWhlShaftBshg_Outside_Arms', 'FlyWhlShaftBshg_Outside_Crst', 'FlyWhlShaftBshg_Outside_Temp', 'MainMtr_Vrms/M_Mtr_Vrms after 17 Mar', 'MainMtr_Apk', 'MainMtr_Arms', 'MainMtr_Crst', 'MainMtr_Temp', 'BullGearBshg_Vrms', 'BullGearBshg_Apk', 'BullGearBshg_Arms', 'BullGearBshg_Crst', 'BullGearBshg_Temp', 'Press_angle', nan, 'FR_Gb_Cnd_Vrms', 'FR_Gb_Cnd_Apk', 'FR_Gb_Cnd_Arms', 'FR_Gb_Cnd_Crst', 'FR_Gb_Cnd_Temp', 'FL_Gb_Cnd_Vrms', 'FL_Gb_Cnd_Apk', 'FL_Gb_Cnd_Arms', 'FL_Gb_Cnd_Crst', 'FL_Gb_Cnd_Temp', 'RR_Gb_Cnd_Vrms', 'RR_Gb_Cnd_Apk', 'RR_Gb_Cnd_Arms', 'RR_Gb_Cnd_Crst', 'RR_Gb_Cnd_Temp', 'RL_Gb_Cnd_Vrms', 'RL_Gb_Cnd_Apk', 'RL_Gb_Cnd_Arms', 'RL_Gb_Cnd_Crst', 'RL_Gb_Cnd_Temp', 'Ram_FR_CNut_Vrms', 'Ram_FR_CNut_Apk', 'Ram_FR_CNut_Arms', 'Ram_FR_CNut_Crst', 'Ram_FR_CNut_Temp', 'Ram_FL_CNut_Vrms', 'Ram_FL_CNut_Apk', 'Ram_FL_CNut_Arms', 'Ram_FL_CNut_Crst', 'Ram_FL_CNut_Temp', 'Ram_RR_CNut_Vrms', 'Ram_RR_CNut_Apk', 'Ram_RR_CNut_Arms', 'Ram_RR_CNut_Crst', 'Ram_RR_CNut_Temp', 'Ram_RL_CNut_Vrms', 'Ram_RL_CNut_Apk', 'Ram_RL_CNut_Arms', 'Ram_RL_CNut_Crst', 'Ram_RL_CNut_Temp', 'Ram_Adj_Mtr_Vrms', 'Ram_Adj_Mtr_Apk', 'Ram_Adj_Mtr_Arms', 'Ram_Adj_Mtr_Crest', 'Ram_Adj_Mtr_Temp', nan, 'CBal_pre_PSI', 'QDC_Drive_Pre_PSI', 'LCBal_Resvr_Pre_PSI', 'RCBal_Resvr_Pre', 'Crwn_HydUnit_Resvr_OilLvl', 'Crwn_HydUnit_HydClutch_Pre', 'Crwn_HydUnit_HydraulicPre', 'Crwn_HydUnit_HydMtrVrms', 'Crwn_HydUnit_HydMtrApk', 'Crwn_HydUnit_HydMtrArms', 'Crwn_HydUnit_HydMtrCrst', 'Crwn_HydUnit_HydMtrTemp', 'Crwn_HydUnit_HydPmp_Vrms', 'Crwn_HydUnit_HydPmp_Apk', 'Crwn_HydUnit_HydPmp_Arms', 'Crwn_HydUnit_HydPmp_Crst', 'Crwn_HydUnit_HydPmp_Temp', 'RadMtr_Vrms', 'RadMtr_Apk', 'RadMtr_Arms', 'RadMtr_Crst', 'RadMtr_Temp', nan, nan, 'Fdr_Pnch_Rler_Pnmatic_Pre', 'Fdr_UpDwn_Pnmatic_Pre', 'Fdr_Guide_Pre', 'Stnr_Pinch_Roller_Pre', 'Stnr_Mtr_Vrms', 'Stnr_Mtr_Apk', 'Stnr_Mtr_Arms', 'Stnr_Mtr_Crst', 'Stnr_Mtr_Temp', 'Stnr_Pmp_HydPre', 'Stnr_Pmp_Vrms', 'Stnr_Pmp_Apk', 'Stnr_Pmp_Arms', 'Stnr_Pmp_Crst', 'Stnr_Pmp_Temp', 'Stnr_HydResvr_OilLvl', 'Stnr_HydMtrVrms', 'Stnr_HydMtrApk', 'Stnr_HydMtrArms', 'Stnr_HydMtrCrst', 'Stnr_HydMtrTemp', 'Stnr_MandrelArmRoller_FwdPre', 'Stnr_MandrelArmRoller_RevPre', 'uncolr_Mandrel_ret_Pre', 'uncolr_Mandrel_Exp_Pre', 'uncolr_Mandrel_JgFwd_Pre', 'uncolr_Mandrel_JgRev_Pre', 'uncolr_ClutchnBrake_Pre', nan, 'DieClamp1_Pre', 'DieClamp2_Pre', 'QDC_UnClamp_Pre', 'QDC_Clamp_Pre', 'QDC_Lift_Pre', 'MainHPU_Psressure_Pre', 'Pnmatic_Driving_Pre', nan, 'CF_LubeBlock_Pre' ...
# {2: ['Xfer_MainPre_PSI'], 3: ['Xfer_UnitHydMtr_Apk', 'Xfer_UnitHydMtr_Vrms', 'Xfer_UnitHydMtr_Arms', 'Xfer_UnitHydMtr_Temp', 'Xfer_HydUnit_OilLvl_UGT526inmm', 'Xfer_UnitHydMtr_Vrms', 'Xfer_UnitHydMtr_Apk', 'Xfer_UnitHydMtr_Arms', 'Xfer_UnitHydMtr_Crst', 'Xfer_UnitHydMtr_Temp'], 4: ['XferHyd_Pre']}
# 12
# 01-Feb-2023 00:28:11.953153
# 4 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Xfer_MainPre_PSI': 1}
# 01-Feb-2023 00:28:11.964199
# 9 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'Xfer_UnitHydMtr_Apk': 1, 'Xfer_UnitHydMtr_Vrms': 1, 'Xfer_UnitHydMtr_Arms': 1, 'Xfer_UnitHydMtr_Temp': 1, 'Xfer_HydUnit_OilLvl_UGT526inmm': 1, 'Xfer_UnitHydMtr_Crst': 1}
# 01-Feb-2023 00:28:11.923892
# 4 {'_id': 0, 'Date': 1, 'Press_Angle': 1, 'XferHyd_Pre': 1}
# {'DieClamp1_Pre': [0.0, 3000.688], 'DieClamp2_Pre': [0.0, 2999.209], 'QDC_UnClamp_Pre': [2.9578, 7.3945], 'QDC_Clamp_Pre': [0.0, 4.4367], 'QDC_Lift_Pre': [0.0, 0.0], 'MainHPU_Psressure_Pre': [2826.178, 2994.772], 'Pnmatic_Driving_Pre': [54.7193, 56.1982], 'FL_UprLink_Pin_Vrms': [0.0, 0.002], 'FL_UprLink_Pin_Apk': [0.2, 44.2], 'FL_UprLink_Pin_Arms': [0.0, 1.8], 'FL_UprLink_Pin_Crst': [3.5, 37.6], 'FL_UprLink_Pin_Temp': [89.6, 95.18001], 'FL_Eccntric_Pin_Vrms': [0.0, 0.0022], 'FL_Eccntric_Pin_Apk': [0.3, 67.2], 'FL_Eccntric_Pin_Arms': [0.1, 2.7], 'FL_Eccntric_Pin_Crst': [2.7, 40.2], 'FL_Eccntric_Pin_TempFar': [90.68001, 99.14], 'Frnt_InterPin_Vrms': [0.0001, 0.0043], 'Frnt_InterPin_Apk': [0.2, 86.0], 'Frnt_InterPin_Arms': [0.0, 2.8], 'Frnt_InterPin_Crst': [3.1, 33.9], 'Frnt_InterPin_Temp': [88.16, 93.2], 'Drive_Shaft_Pin_Vrms': [0.0, 0.0039], 'Drive_Shaft_Pin_Apk': [0.4, 125.7], 'Drive_Shaft_Pin_Arms': [0.1, 5.6], 'Drive_Shaft_Pin_Crst': [2.0, 43.4], 'Drive_Shaft_Pin_Temp': [90.32001, 98.6], 'FR_Eccntric_Pin_Vrms': [0.0, 0.0035], 'FR_Eccntric_Pin_Apk': [0.3, 69.9], 'FR_Eccntric_Pin_Arms': [0.1, 3.6], 'FR_Eccntric_Pin_Crst': [2.7, 40.8], 'FR_Eccntric_Pin_Temp': [89.24001, 97.34], 'FR_UprLink_Pin_Vrms': [0.0, 0.0027], 'FR_UprLink_Pin_Apk': [0.2, 107.7], 'FR_UprLink_Pin_Arms': [0.0, 3.0], 'FR_UprLink_Pin_Crst': [2.7, 38.8], 'FR_UprLink_Pin_Temp': [88.88, 93.38], 'RR_EccntricBshg_Vrms': [0.0, 0.0032], 'RR_EccntricBshg_Apk': [0.2, 17.0], 'RR_EccntricBshg_Arms': [0.1, 1.5], 'RR_EccntricBshg_Crst': [3.0, 23.9], 'RR_EccntricBshg_Temp': [89.6, 94.82001], 'RR_UprLink_Bshg_Vrms': [0.0, 0.0022], 'RR_UprLink_Bshg_Apk': [0.2, 92.62000000001862], 'RR_UprLink_Bshg_Arms': [0.1, 2.7], 'RR_UprLink_Bshg_Crst': [3.2, 40.0], 'RR_UprLink_Bshg_Temp': [89.42, 93.56], 'FlyWhlShaftBshg_Outside_Vrms': [0.0001, 0.0039], 'FlyWhlShaftBshg_Outside_Apk': [0.9, 37.2], 'FlyWhlShaftBshg_Outside_Arms': [0.2, 2.4], 'FlyWhlShaftBshg_Outside_Crst': [2.6, 17.4], 'FlyWhlShaftBshg_Outside_Temp': [98.42001, 103.82], 'RL_Eccntric